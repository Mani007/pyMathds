# %%
# creating data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
in_data_size = np.random.choice([1100+x for x in range(60)],size=(10))
in_data_size
# Out:
# array([1125, 1131, 1102, 1133, 1104, 1136, 1139, 1119, 1152, 1114])

# %%
out_data_price = np.random.choice([100000+x for x in range(100,1000,50)],size=(10))
out_data_price
# Out:
# array([100650, 100350, 100150, 100900, 100600, 100250, 100400, 100450,
#        100550, 100500])

# %%
# plotting the scatter plot
plt.scatter(in_data_size,out_data_price)
plt.show()
