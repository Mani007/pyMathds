# %%
# creating data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
in_data_size = np.random.choice([1100+x for x in range(60)],size=(20))
in_data_size
# Out:
# array([1104, 1118, 1136, 1130, 1153, 1131, 1117, 1135, 1107, 1154, 1124,
#        1146, 1153, 1141, 1151, 1104, 1140, 1120, 1150, 1107])

# %%
out_data_price = np.random.choice([100000+x for x in range(100,1000,50)],size=(20))
out_data_price
# Out:
# array([100500, 100750, 100900, 100600, 100100, 100550, 100150, 100900,
#        100400, 100850, 100900, 100400, 100550, 100750, 100850, 100400,
#        100150, 100450, 100500, 100700])

# %%
# plotting the scatter plot
plt.scatter(in_data_size,out_data_price)
plt.show()
