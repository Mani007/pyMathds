# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.7482, 0.2277, 0.7778],
#         [0.1291, 0.0963, 0.2101],
#         [0.3399, 0.4899, 0.5182],
#         [0.1586, 0.8605, 0.9552],
#         [0.2305, 0.9781, 0.1295]])
