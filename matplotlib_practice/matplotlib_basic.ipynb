# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = np.random.random(20)*100 # 20 random number between 0 and 1 then multiplied by 100
y_data = np.random.random(20)*100

# %%
plt.scatter(x_data,y_data, c='#42f557', marker='+', s=120)
plt.show()

# %%
#x_dataline = np.random.randint(10, size=20)
x_dataline = [2007+ x for x in range(15)]
x_dataline
# Out:
# [2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
y_dataline = np.random.randint(10,size=15)
y_dataline
# Out:
# array([1, 6, 1, 7, 7, 9, 7, 3, 1, 8, 3, 7, 2, 5, 6], dtype=int32)

# %%
plt.plot(x_dataline,y_dataline, c='g', lw=3, linestyle='--') # line plot
plt.show()

# %%
data = ["paris", "barcelona", "kolkata", "new york"]
import random
x  = [random.sample(data,1) for _ in range(5)]
x
# Out:
# [['kolkata'], ['new york'], ['barcelona'], ['kolkata'], ['paris']]

# %%
x_datacategory = ['A','B','C','D','E','F','G','H','I']
y_datacategory = np.random.randint(20,size=9)
y_datacategory
# Out:
# array([ 5,  5,  9, 17, 10, 15,  2,  7,  7], dtype=int32)

# %%
plt.bar(x_datacategory,y_datacategory)
plt.show()

# %%
plt.bar(x_datacategory,y_datacategory, color='green', align='edge', edgecolor='blue', width=0.7)
plt.show()

# %%
x_datacategory = ['A','B','C','D','E','F','G','H','I']
y_datacategory1 = np.random.randint(20,size=9)
y_datacategory2 = np.random.randint(20,size=9)

# %%
# Histogram
x_hist1 = np.random.normal(20,5,50) # mean 20, median 5 and sample of 50
x_hist1
# Out:
# array([ 9.40329249, 25.73074676, 17.82297978, 19.491073  , 18.41899026,
#        19.91803078, 20.31499401, 19.26252726, 13.96542166, 18.55671654,
#        11.42762538, 22.49071925, 12.77792823, 17.81588046,  9.27915162,
#        24.06725961, 19.96736056, 19.88702064, 14.6764458 , 12.07629271,
#        10.7300871 , 21.32668154, 26.98327726, 16.8807383 , 20.11686495,
#        19.68946911, 15.76543975, 24.14042601, 13.00842034, 21.21955638,
#        23.58692414, 20.53761293, 23.5160628 , 18.46498359, 23.51287318,
#        30.05450039, 15.33315146, 24.89209862, 23.22154557, 19.94293353,
#        20.16084198, 19.00795283, 20.22277108, 28.94062013, 16.08842852,
#        18.74140193, 23.92658685, 20.59099474, 22.56176758, 26.27910162])

# %%
x_hist1 = np.random.normal(20,5,1000) # mean 20, median 5 and sample of 1000
plt.hist(x_hist1)
plt.show()

# %%
x_hist1 = np.random.normal(20,5,1000) # mean 20, median 5 and sample of 1000
plt.hist(x_hist1, bins=5)
plt.show()

# %%
x_hist1 = np.random.normal(20,5,1000) # mean 20, median 5 and sample of 1000
plt.hist(x_hist1, bins=[x_hist1.min(),18,19,20,21, x_hist1.max()])
plt.show()

# %%
x_hist1 = np.random.normal(20,5,1000) # mean 20, median 5 and sample of 1000
plt.hist(x_hist1,cumulative=True)
plt.show()

# %%
# pie charts
x_datapie = ['A','B','C','D','E','F','G','H','I']
y_datapie1 = np.random.randint(20,size=9)
y_datapie2 = np.random.randint(20,size=9)

# %%
plt.pie(y_datapie1, labels=x_datapie)
plt.show()

# %%
x_datapie1 = ['A','B','C','D','E']
y_datapie11 = np.random.randint(20,size=5)
explode1 = [0,0,0,0.3,0]
plt.pie(y_datapie11, labels=x_datapie1, explode=explode1, autopct='%.2f%%', pctdistance=1.4, startangle=90)
plt.show()

# %%
# box plot 
x_box1 = np.random.normal(20, 5, 25)
plt.boxplot(x_box1)
plt.show()

# %%
x_datasub = [2007 + x for x in range(10)]
y_datasub = np.random.randint(20,size=10)
y_ticks1 = [x for x in range(0,21,2)]
plt.plot(x_datasub,y_datasub)
plt.title("Some plot")
plt.xlabel("At X axis")
plt.ylabel("At Y axis")
plt.yticks(y_ticks1, [f"{x}K USD"  for x in y_ticks1 ])
plt.show()

# %%
import matplotlib.style as style
style.use('ggplot')
stock1 = np.random.randint(100,150, size=15)
stock2 = np.random.randint(100,150, size=15)
stock3 = np.random.randint(100,150, size=15)
plt.plot(stock1, label='A')
plt.plot(stock2, label='B')
plt.plot(stock3, label='C')
plt.legend(loc='upper right')
plt.show()

# %%
x1, x2 = np.random.randint(100,150,size=10), np.random.randint(100,150,size=10)
y1, y2 = np.arange(10), np.arange(10)
plt.figure(1)
plt.scatter(x1,y1)
plt.figure(2)
plt.plot(x2,y2)
plt.show()

# %%
xaxisplot = np.arange(25)
fig, axs = plt.subplots(2,2)
axs[0,0].plot(xaxisplot,np.random.randint(10,50, size= 25))
axs[0,0].set_title(" Basic plot")
axs[0,1].scatter(xaxisplot,np.random.randint(10,50, size= 25))
axs[0,1].set_title(" Basic scatter")
axs[1,0].plot(xaxisplot,np.sin(xaxisplot))
axs[1,0].set_title(" Sin wave")
axs[1,1].plot(xaxisplot,np.cos(xaxisplot))
axs[1,1].set_title(" Cos wave")
fig.suptitle("Four plots")
plt.show()

# %%
ax = plt.axes(projection='3d')
xaxisval = np.random.randint(100,size=25)
yaxisval = np.random.randint(100,size=25)
zaxisval = np.random.randint(100,size=25)
ax.plot(xaxisval,yaxisval,zaxisval)
plt.show()
